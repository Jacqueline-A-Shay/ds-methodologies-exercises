# %%
import pandas as pd

# %% [markdown]
# **SET DATA AS INDEX BEFORE PLOTt**

# %%
df = pd.read_csv('coffee_consumption.csv')

# %%
df.head()
# Out:
#          date  coffee_consumption
# 0  2019-01-01           14.301915
# 1  2019-01-02           12.905900
# 2  2019-01-03           10.046015
# 3  2019-01-04            6.354805
# 4  2019-01-07            8.545563

# %%
pd.to_datetime('2019-01-01')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.to_datetime('Nov:19', format = '%b:%y')
# Out:
# Timestamp('2019-11-01 00:00:00')

# %%
df.dtypes
# Out:
# date                   object
# coffee_consumption    float64
# dtype: object

# %%
df.date = pd.to_datetime(df.date)

# %%
df = df.set_index('date').sort_index()

# %%
#filter
df['2019']
df['2019-01':'2019-03']
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456
# 2019-01-11           11.872667
# 2019-01-14            9.198816
# 2019-01-15           11.753337
# 2019-01-16           11.567694
# 2019-01-17            9.429428
# 2019-01-18            9.376213
# 2019-01-21           11.343439
# 2019-01-22           10.945944
# 2019-01-23            8.599186
# 2019-01-24            8.141553
# 2019-01-25            9.421176
# 2019-01-28           12.295298
# 2019-01-29           10.336273
# 2019-01-30           12.488651
# 2019-01-31            9.035046
# 2019-02-01            9.042273
# 2019-02-04           12.673222
# 2019-02-05           11.562866
# 2019-02-06            9.532721
# 2019-02-07           10.128274
# 2019-02-08           12.080342
# ...

# %%
# inclusive, slice up to certain day
df[:'2019-04']
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456
# 2019-01-11           11.872667
# 2019-01-14            9.198816
# 2019-01-15           11.753337
# 2019-01-16           11.567694
# 2019-01-17            9.429428
# 2019-01-18            9.376213
# 2019-01-21           11.343439
# 2019-01-22           10.945944
# 2019-01-23            8.599186
# 2019-01-24            8.141553
# 2019-01-25            9.421176
# 2019-01-28           12.295298
# 2019-01-29           10.336273
# 2019-01-30           12.488651
# 2019-01-31            9.035046
# 2019-02-01            9.042273
# 2019-02-04           12.673222
# 2019-02-05           11.562866
# 2019-02-06            9.532721
# 2019-02-07           10.128274
# 2019-02-08           12.080342
# ...

# %%
# usually want every single day, but apparently there's missing data
# ex: missing 01-05 & 01-06
df['2019-01':'2019-02']
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456
# 2019-01-11           11.872667
# 2019-01-14            9.198816
# 2019-01-15           11.753337
# 2019-01-16           11.567694
# 2019-01-17            9.429428
# 2019-01-18            9.376213
# 2019-01-21           11.343439
# 2019-01-22           10.945944
# 2019-01-23            8.599186
# 2019-01-24            8.141553
# 2019-01-25            9.421176
# 2019-01-28           12.295298
# 2019-01-29           10.336273
# 2019-01-30           12.488651
# 2019-01-31            9.035046
# 2019-02-01            9.042273
# 2019-02-04           12.673222
# 2019-02-05           11.562866
# 2019-02-06            9.532721
# 2019-02-07           10.128274
# 2019-02-08           12.080342
# ...

# %%
# add the missing day, but the value is nan now
df.asfreq('D')
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-05                 NaN
# 2019-01-06                 NaN
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456
# 2019-01-11           11.872667
# 2019-01-12                 NaN
# 2019-01-13                 NaN
# 2019-01-14            9.198816
# 2019-01-15           11.753337
# 2019-01-16           11.567694
# 2019-01-17            9.429428
# 2019-01-18            9.376213
# 2019-01-19                 NaN
# 2019-01-20                 NaN
# 2019-01-21           11.343439
# 2019-01-22           10.945944
# 2019-01-23            8.599186
# 2019-01-24            8.141553
# 2019-01-25            9.421176
# 2019-01-26                 NaN
# 2019-01-27                 NaN
# 2019-01-28           12.295298
# 2019-01-29           10.336273
# ...

# %%
# forward fill, but can be problemetic EX: weekend and weekday consumption is different
#.bfill() will be backward fill
# df.asfreq('D').fill(0) will fill zero to ALL nan
df['2019-01'].asfreq('D').ffill()
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-05            6.354805
# 2019-01-06            6.354805
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456
# 2019-01-11           11.872667
# 2019-01-12           11.872667
# 2019-01-13           11.872667
# 2019-01-14            9.198816
# 2019-01-15           11.753337
# 2019-01-16           11.567694
# 2019-01-17            9.429428
# 2019-01-18            9.376213
# 2019-01-19            9.376213
# 2019-01-20            9.376213
# 2019-01-21           11.343439
# 2019-01-22           10.945944
# 2019-01-23            8.599186
# 2019-01-24            8.141553
# 2019-01-25            9.421176
# 2019-01-26            9.421176
# 2019-01-27            9.421176
# 2019-01-28           12.295298
# 2019-01-29           10.336273
# ...

# %%
# all of last day
df.asfreq('M')
# Out:
#             coffee_consumption
# date
# 2019-01-31            9.035046
# 2019-02-28            9.093397
# 2019-03-31                 NaN
# 2019-04-30            7.086039
# 2019-05-31           10.818797
# 2019-06-30                 NaN
# 2019-07-31           10.790037
# 2019-08-31                 NaN
# 2019-09-30           11.282275
# 2019-10-31           11.734257
# 2019-11-30                 NaN
# 2019-12-31           10.168315

# %%
#basically a groupby, so need agg method otherwise will only return groupby object
df.resample('M')
# Out:
# DatetimeIndexResampler [freq=<MonthEnd>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
df.resample('M').median()
# Out:
#             coffee_consumption
# date
# 2019-01-31            9.429428
# 2019-02-28           10.264846
# 2019-03-31           10.784550
# 2019-04-30            9.662424
# 2019-05-31           11.130547
# 2019-06-30            9.059233
# 2019-07-31           10.790037
# 2019-08-31           10.123895
# 2019-09-30           10.098127
# 2019-10-31           10.708118
# 2019-11-30           10.309799
# 2019-12-31           10.270358

# %%
df.resample('M').agg(['median','mean','min','max','count'])
# Out:
#            coffee_consumption
#                        median       mean       min        max count
# date
# 2019-01-31           9.429428  10.170728  6.354805  14.301915    23
# 2019-02-28          10.264846  10.301943  6.805306  12.673222    20
# 2019-03-31          10.784550  10.465667  5.680393  14.551441    21
# 2019-04-30           9.662424  10.092301  6.534674  14.036570    22
# 2019-05-31          11.130547  10.803482  6.220478  14.952719    23
# 2019-06-30           9.059233   9.182825  6.010460  13.446564    20
# 2019-07-31          10.790037  10.794238  6.500401  17.043445    23
# 2019-08-31          10.123895  10.182139  7.429678  13.665973    22
# 2019-09-30          10.098127  10.270905  6.358469  15.347007    21
# 2019-10-31          10.708118  10.615371  7.381459  16.811112    23
# 2019-11-30          10.309799  10.310467  6.391103  14.741298    21
# 2019-12-31          10.270358  10.453933  7.056316  14.623106    22

# %%
df.resample('Q').agg(['median','mean','min','max','count'])
# Out:
#            coffee_consumption
#                        median       mean       min        max count
# date
# 2019-03-31          10.240899  10.308509  5.680393  14.551441    64
# 2019-06-30           9.773824  10.064111  6.010460  14.952719    65
# 2019-09-30          10.140210  10.423690  6.358469  17.043445    66
# 2019-12-31          10.432917  10.464543  6.391103  16.811112    66

# %%
df.resample('3W').agg(['median','mean','min','max','count'])
# Out:
#            coffee_consumption
#                        median       mean        min        max count
# date
# 2019-01-06          11.475958  10.902159   6.354805  14.301915     4
# 2019-01-27           9.410101   9.744190   7.219271  11.872667    15
# 2019-02-17          10.384167  10.855301   9.035046  12.673222    15
# 2019-03-10           9.093397   9.413472   5.680393  12.295259    15
# 2019-03-31          11.296137  11.062768   6.552509  14.551441    15
# 2019-04-21           9.603164  10.222518   6.534674  14.036570    15
# 2019-05-12           9.970773  10.092044   7.020795  13.196664    15
# 2019-06-02          11.130547  11.052819   6.220478  14.952719    15
# 2019-06-23           9.773824   9.592148   7.184009  12.129608    15
# 2019-07-14           8.959335   9.491908   6.010460  15.219210    15
# 2019-08-04          10.866374  10.883995   6.500401  17.043445    15
# 2019-08-25          10.130880  10.426981   7.429678  13.665973    15
# ...

# %%
#pandas skips nan
import numpy as np
pd.Series([1,2,3,np.nan,4]).mean()
# Out:
# 2.5

# %%
#just by month .groupby (across year, disregard year 2019-02 and 2018-02 will be binned together)
#df.resample will sep by year, 2019-02 is one row, 2018-02 is in another row, not pivotted together

# %%
jan = df['2019-01'].copy()
jan.rolling(3).mean()
# Out:
#             coffee_consumption
# date
# 2019-01-01                 NaN
# 2019-01-02                 NaN
# 2019-01-03           12.417943
# 2019-01-04            9.768907
# 2019-01-07            8.315461
# 2019-01-08            8.103490
# 2019-01-09            8.391645
# 2019-01-10            8.655943
# 2019-01-11            9.476798
# 2019-01-14           10.136647
# 2019-01-15           10.941607
# 2019-01-16           10.839949
# 2019-01-17           10.916820
# 2019-01-18           10.124445
# 2019-01-21           10.049693
# 2019-01-22           10.555199
# 2019-01-23           10.296190
# 2019-01-24            9.228895
# 2019-01-25            8.720639
# 2019-01-28            9.952676
# 2019-01-29           10.684249
# 2019-01-30           11.706741
# 2019-01-31           10.619990

# %%
#move 1 position down
jan.shift(1)
#.diff(7)  # compare weekly
# Out:
#             coffee_consumption
# date
# 2019-01-01                 NaN
# 2019-01-02           14.301915
# 2019-01-03           12.905900
# 2019-01-04           10.046015
# 2019-01-07            6.354805
# 2019-01-08            8.545563
# 2019-01-09            9.410101
# 2019-01-10            7.219271
# 2019-01-11            9.338456
# 2019-01-14           11.872667
# 2019-01-15            9.198816
# 2019-01-16           11.753337
# 2019-01-17           11.567694
# 2019-01-18            9.429428
# 2019-01-21            9.376213
# 2019-01-22           11.343439
# 2019-01-23           10.945944
# 2019-01-24            8.599186
# 2019-01-25            8.141553
# 2019-01-28            9.421176
# 2019-01-29           12.295298
# 2019-01-30           10.336273
# 2019-01-31           12.488651

# %%
# time zone
df # no time zone,
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456
# 2019-01-11           11.872667
# 2019-01-14            9.198816
# 2019-01-15           11.753337
# 2019-01-16           11.567694
# 2019-01-17            9.429428
# 2019-01-18            9.376213
# 2019-01-21           11.343439
# 2019-01-22           10.945944
# 2019-01-23            8.599186
# 2019-01-24            8.141553
# 2019-01-25            9.421176
# 2019-01-28           12.295298
# 2019-01-29           10.336273
# 2019-01-30           12.488651
# 2019-01-31            9.035046
# 2019-02-01            9.042273
# 2019-02-04           12.673222
# 2019-02-05           11.562866
# 2019-02-06            9.532721
# 2019-02-07           10.128274
# 2019-02-08           12.080342
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#                '2019-12-24', '2019-12-25', '2019-12-26', '2019-12-27',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='date', length=261, freq=None)

# %%
type(df.index.tz)
# Out:
# NoneType

# %%
#specify time zone object
df.index.tz_localize('America/Chicago').tz
# Out:
# <DstTzInfo 'America/Chicago' LMT-1 day, 18:09:00 STD>

# %%
central_timestamps = df.index.tz_localize('America/Chicago')
central_timestamps
# Out:
# DatetimeIndex(['2019-01-01 00:00:00-06:00', '2019-01-02 00:00:00-06:00',
#                '2019-01-03 00:00:00-06:00', '2019-01-04 00:00:00-06:00',
#                '2019-01-07 00:00:00-06:00', '2019-01-08 00:00:00-06:00',
#                '2019-01-09 00:00:00-06:00', '2019-01-10 00:00:00-06:00',
#                '2019-01-11 00:00:00-06:00', '2019-01-14 00:00:00-06:00',
#                ...
#                '2019-12-18 00:00:00-06:00', '2019-12-19 00:00:00-06:00',
#                '2019-12-20 00:00:00-06:00', '2019-12-23 00:00:00-06:00',
#                '2019-12-24 00:00:00-06:00', '2019-12-25 00:00:00-06:00',
#                '2019-12-26 00:00:00-06:00', '2019-12-27 00:00:00-06:00',
#                '2019-12-30 00:00:00-06:00', '2019-12-31 00:00:00-06:00'],
#               dtype='datetime64[ns, America/Chicago]', name='date', length=261, freq=None)

# %%
# disregard daylight saving
# useful with sattelite, server stuff, across globe cooperates
central_timestamps.tz_convert('UTC')
# Out:
# DatetimeIndex(['2019-01-01 06:00:00+00:00', '2019-01-02 06:00:00+00:00',
#                '2019-01-03 06:00:00+00:00', '2019-01-04 06:00:00+00:00',
#                '2019-01-07 06:00:00+00:00', '2019-01-08 06:00:00+00:00',
#                '2019-01-09 06:00:00+00:00', '2019-01-10 06:00:00+00:00',
#                '2019-01-11 06:00:00+00:00', '2019-01-14 06:00:00+00:00',
#                ...
#                '2019-12-18 06:00:00+00:00', '2019-12-19 06:00:00+00:00',
#                '2019-12-20 06:00:00+00:00', '2019-12-23 06:00:00+00:00',
#                '2019-12-24 06:00:00+00:00', '2019-12-25 06:00:00+00:00',
#                '2019-12-26 06:00:00+00:00', '2019-12-27 06:00:00+00:00',
#                '2019-12-30 06:00:00+00:00', '2019-12-31 06:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='date', length=261, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.plot()

# %%
plt.rc('figure', figsize = (12,9))
df.plot()

# %%
df.resample('M').coffee_consumption.mean().plot()

# %%
#.assign() won't destruct/ add/ minus original dataframe
(df.asfreq('D')
    .fillna(0)
    .assign(moving_monthly_avg = lambda df: df.coffee_consumption.rolling(30).mean())
    .plot())

# %%
#.assign() won't destruct/ add/ minus original dataframe
(df.asfreq('D')
    .fillna(0)
    .assign(moving_monthly_avg = lambda df: df.coffee_consumption.rolling(30).mean())
     .assign(monthly_avg=lambda df: df.coffee_consumption.resample('M').transform('mean'))
    .plot(alpha = 0.5))

# %%
(df.asfreq('D')
 .fillna(0)
 .assign(moving_monthly_avg=lambda df: df.coffee_consumption.rolling(30).mean())
 .assign(monthly_avg=lambda df: df.coffee_consumption.resample('M').transform('mean'))
 .plot(alpha=.7))
