# %%
import pandas
import acquire
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = acquire.get_all_data()
# Out:
# Fetching page 2 of 183
# Fetching page 3 of 183
# Fetching page 4 of 183
# Fetching page 5 of 183
# Fetching page 6 of 183
# Fetching page 7 of 183
# Fetching page 8 of 183
# Fetching page 9 of 183
# Fetching page 10 of 183
# Fetching page 11 of 183
# Fetching page 12 of 183
# Fetching page 13 of 183
# Fetching page 14 of 183
# Fetching page 15 of 183
# Fetching page 16 of 183
# Fetching page 17 of 183
# Fetching page 18 of 183
# Fetching page 19 of 183
# Fetching page 20 of 183
# Fetching page 21 of 183
# Fetching page 22 of 183
# Fetching page 23 of 183
# Fetching page 24 of 183
# Fetching page 25 of 183
# Fetching page 26 of 183
# Fetching page 27 of 183
# Fetching page 28 of 183
# Fetching page 29 of 183
# Fetching page 30 of 183
# Fetching page 31 of 183
# Fetching page 32 of 183
# Fetching page 33 of 183
# Fetching page 34 of 183
# Fetching page 35 of 183
# Fetching page 36 of 183
# Fetching page 37 of 183
# Fetching page 38 of 183
# Fetching page 39 of 183
# ...

# %%
df.head()
# Out:
#    item_id  sale_amount                      sale_date  sale_id  store_id  \
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1         1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2         1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3         1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4         1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5         1
#
#   item_brand                       item_name  item_price   item_upc12  \
# 0   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 1   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 2   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 3   Riceland  Riceland American Jazmine Rice        0.84  35200264013
# 4   Riceland  Riceland American Jazmine Rice        0.84  35200264013
#
#     item_upc14           store_address   store_city store_state store_zipcode
# ...

# %%
fmt = '%a, %d %b %Y %H:%M:%S %Z'
pd.to_datetime(df.sale_date, format = fmt)
# df.sale_date = pd.to_datetime('now').tz_localize('America/Chicago').strftime(fmt) # check my set time format

# %%
df.sort_values(by = 'sale_date').set_index('sale_date')

# %%
df.set_index('sale_date')

# %%
df['month'] = df.index.strftime('%m-%b')
df['weekday']= df.index.strftime('%w-%a')
df[['month','weekday']] = df.index.strftime.head()

# %%
(df.sale_amount.astype('int') == df.sale_amount).all()

# %%
df.sale_amount.astype('int') == df.sale_amount

# %%
df.hist()

# %%
df['sales_total'] = df.sale_amount * df.item_price
sales_by_day = df.resample('D')[['sales_total']].sum()
sales_by_day['dif_with_last_day'] = sales_by_day.sales_total.diff()

# %%
def prep_store_data(df):
    #parse date col and set it as the index
    # add some time components as features
    # derive the total sales
    return df
def get_sales_by_day(df):

# %%
import acq
