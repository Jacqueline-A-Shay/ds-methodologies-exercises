# %%
import requests
import pandas as pd

# %%
base_url = 'https://python.zach.lol/api/v1/sales'
response = requests.get(base_url)

sale_data = response.json()
sale= pd.DataFrame(sale_data['payload']['sales'])

# %%
sale
# Out:
#       item  sale_amount                      sale_date  sale_id  store
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# 5        1         12.0  Sun, 06 Jan 2013 00:00:00 GMT        6      1
# 6        1         10.0  Mon, 07 Jan 2013 00:00:00 GMT        7      1
# 7        1          9.0  Tue, 08 Jan 2013 00:00:00 GMT        8      1
# 8        1         12.0  Wed, 09 Jan 2013 00:00:00 GMT        9      1
# 9        1          9.0  Thu, 10 Jan 2013 00:00:00 GMT       10      1
# 10       1          9.0  Fri, 11 Jan 2013 00:00:00 GMT       11      1
# 11       1          7.0  Sat, 12 Jan 2013 00:00:00 GMT       12      1
# ...

# %%
def acquire():
    
    #response = requests.get(base_url)
    for page in range(1,5):
        base_url = 'https://python.zach.lol/api/v1/sales'
        response = requests.get(base_url + '?page={}'.format(page))
        sale= pd.DataFrame(response.json()['payload']['sales'])
        sales = pd.concat([sales, sale])
    return sales

# %%
def acquire():
    for page in range(1,5):
        base_url = 'https://python.zach.lol/api/v1/sales'
        response = requests.get(base_url + '?page={}'.format(page))
        sales = pd.DataFrame()
        sale= pd.DataFrame(response.json()['payload']['sales'])
        sales = pd.concat([sales, sale])
    return sales

# %%
acquire()
# Out:
#       item  sale_amount                      sale_date  sale_id  store
# 0        1         13.0  Tue, 28 Jan 2014 00:00:00 GMT    15001      9
# 1        1         16.0  Wed, 29 Jan 2014 00:00:00 GMT    15002      9
# 2        1         15.0  Thu, 30 Jan 2014 00:00:00 GMT    15003      9
# 3        1         20.0  Fri, 31 Jan 2014 00:00:00 GMT    15004      9
# 4        1         18.0  Sat, 01 Feb 2014 00:00:00 GMT    15005      9
# 5        1         17.0  Sun, 02 Feb 2014 00:00:00 GMT    15006      9
# 6        1          7.0  Mon, 03 Feb 2014 00:00:00 GMT    15007      9
# 7        1         14.0  Tue, 04 Feb 2014 00:00:00 GMT    15008      9
# 8        1         16.0  Wed, 05 Feb 2014 00:00:00 GMT    15009      9
# 9        1         15.0  Thu, 06 Feb 2014 00:00:00 GMT    15010      9
# 10       1         18.0  Fri, 07 Feb 2014 00:00:00 GMT    15011      9
# 11       1         21.0  Sat, 08 Feb 2014 00:00:00 GMT    15012      9
# ...

# %%
def get_sales():
    base_url = "http://python.zach.lol"
    response = requests.get(base_url + "/api/v1/sales")

   #maxpage = response.json()["payload"]["max_page"] + 1
    sales = pd.DataFrame()

    for page in range(1,5):
        response = requests.get(base_url + "/api/v1/sales?page={}".format(page))
        sale_page = pd.DataFrame(response.json()["payload"]["sales"])
        sales = pd.concat([sales,sale_page])
    return sales

# %%
# Out:
#       item  sale_amount                      sale_date  sale_id  store
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# 5        1         12.0  Sun, 06 Jan 2013 00:00:00 GMT        6      1
# 6        1         10.0  Mon, 07 Jan 2013 00:00:00 GMT        7      1
# 7        1          9.0  Tue, 08 Jan 2013 00:00:00 GMT        8      1
# 8        1         12.0  Wed, 09 Jan 2013 00:00:00 GMT        9      1
# 9        1          9.0  Thu, 10 Jan 2013 00:00:00 GMT       10      1
# 10       1          9.0  Fri, 11 Jan 2013 00:00:00 GMT       11      1
# 11       1          7.0  Sat, 12 Jan 2013 00:00:00 GMT       12      1
# ...
