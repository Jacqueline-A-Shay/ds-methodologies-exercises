# %%
import explore

# %%
df = explore.months_to_years()
df.head()
# Out:
#              tenure  monthly_charges  total_charges  tenure_years
# customer_id
# 0013-SMEOE       71           109.70        7904.25           6.0
# 0014-BMAQU       63            84.65        5377.80           5.0
# 0016-QLJIS       65            90.45        5957.90           5.0
# 0017-DINOC       54            45.20        2460.55           4.0
# 0017-IUDMW       72           116.80        8456.75           6.0

# %%
df["tenure_years"] = df.tenure_years.astype("category")

# %%
sns.violinplot(x="tenure_years", y="total_charges", data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.barplot(x="tenure_years", y="total_charges", data=df)

# %%
sns.boxplot(x="tenure_years", y="total_charges", data=df)

# %%
fig, axes = plt.subplots(ncols=3, nrows=1)
for i, ax in zip(range(10), axes.flat):
    sns.boxplot(x="tenure_years", y="total_charges", data=df)

# %%
	fig = plt.figure(figsize=(6, 6))
	grid = plt.GridSpec(nrows = 1, ncols = 6, hspace = 0.2, wspace = 0.2)
	# assign grid for each plot
	violin = fig.add_subplot(grid[0:1, 0:])
	box = fig.add_subplot(grid[2:3, 0:])
	bar = fig.add_subplot(grid[4:5, 0:])
	# fill actual plot into the grids
	violin.plot(x="tenure_years", y="total_charges", data=df)
	box.plot(x="tenure_years", y="total_charges", data=df)
	bar.plot(x="tenure_years", y="total_charges", data=df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-8837b30c320f> in <module>
#       3 # assign grid for each plot
#       4 violin = fig.add_subplot(grid[0:1, 0:])
# ----> 5 box = fig.add_subplot(grid[2:3, 0:])
#       6 bar = fig.add_subplot(grid[4:5, 0:])
#       7 # fill actual plot into the grids
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/gridspec.py in __getitem__(self, key)
#     173                 raise ValueError("unrecognized subplot spec")
#     174             num1, num2 = np.ravel_multi_index(
# --> 175                 [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     176                 (nrows, ncols))
#     177         else:  # Single key
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/gridspec.py in _normalize(key, size, axis)
#     153                 if stop > start:
# ...

# %%
fig = plt.figure(figsize=(6, 12))
grid = plt.GridSpec(nrows = 1, ncols = 6, hspace = 0.2, wspace = 0.2)
x = "tenure_years"
y = "total_charges"

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 4):
    ax = fig.add_subplot(1, 3, i)


violin = fig.add_subplot(grid[0, 0])
box = fig.add_subplot(grid[0, 1:2])
bar = fig.add_subplot(grid[0, 2:3])
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# fill actual plot into the grids
violin.plot(x, y , data=df)
box.plot(x, y , data=df)
bar.plot(x, y , data=df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-0962dc8cf1e1> in <module>
#      13
#      14 # fill actual plot into the grids
# ---> 15 violin.plot(x, y , data=df)
#      16 box.plot(x, y , data=df)
#      17 bar.plot(x, y , data=df)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# ...

# %%
def main():
    nrows = 3
    fig, axes = plt.subplots(nrows, 1)

    for row in axes:
        violin = sns.violinplot(x="tenure_years", y="total_charges", data=df)
        box = sns.boxplot(x="tenure_years", y="total_charges", data=df)
        bar = sns.barplot(x="tenure_years", y="total_charges", data=df)
        row[0].plot(violin)
        row[1].plot(box)
        row[2].plot(bar)
        plot(row, violin, box, bar)
    plt.show()    
    
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-ccd5cd57bd1b> in <module>
#      13     plt.show()
#      14
# ---> 15 main()
#
# <ipython-input-64-ccd5cd57bd1b> in main()
#       7         box = sns.boxplot(x="tenure_years", y="total_charges", data=df)
#       8         bar = sns.barplot(x="tenure_years", y="total_charges", data=df)
# ----> 9         row[0].plot(violin)
#      10         row[1].plot(box)
#      11         row[2].plot(bar)
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
list(df.columns)
# Out:
# ['tenure', 'monthly_charges', 'total_charges', 'tenure_years']
