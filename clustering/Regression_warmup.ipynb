# %%
# general
import pandas as pd
import numpy as mp
# vis
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pydataset import data

# %%
df = data('faithful')

# %%
df.head()
# Out:
#    eruptions  waiting
# 1      3.600       79
# 2      1.800       54
# 3      3.333       74
# 4      2.283       62
# 5      4.533       85

# %%
df.describe()
# Out:
#         eruptions     waiting
# count  272.000000  272.000000
# mean     3.487783   70.897059
# std      1.141371   13.594974
# min      1.600000   43.000000
# 25%      2.162750   58.000000
# 50%      4.000000   76.000000
# 75%      4.454250   82.000000
# max      5.100000   96.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272 entries, 1 to 272
# Data columns (total 2 columns):
# eruptions    272 non-null float64
# waiting      272 non-null int64
# dtypes: float64(1), int64(1)
# memory usage: 6.4 KB

# %%
df.corr()
# Out:
#            eruptions   waiting
# eruptions   1.000000  0.900811
# waiting     0.900811  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.scatterplot("eruptions", "waiting", data = df)

# %%
sns.violinplot(y="eruptions", data = df)

# %%
sns.boxplot(y="eruptions", data = df)

# %%
sns.violinplot(y="waiting", data = df)

# %%
sns.boxplot(y="waiting", data = df)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X, y = df[['waiting']], df['eruptions']

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression().fit(X,y)

# %%
predictions = model.predict(X)

rmse = sqrt(mean_squared_error(y, predictions))

plt.figure(figsize = (14,8))

plt.scatter(X, y, label = "Actual", alpha = .6)
plt.scatter(X, predictions, label = "Prediction", alpha = .6)

plt.xlabel("Waiting (Minutes)")
plt.ylabel("Eruptions (Minutes)")
plt.title("Actual vs Predicted Eruptions")

plt.yticks(range(0, 7))
# np.arange(0, 20, 2)
# 2 is step
# 0, 2, 4...

plt.text(50, 5, f'RMSE: {rmse:.4f}', size = 16)

plt.legend()

# %%
df['yhat'] = predictions
df = df[['waiting', 'eruptions','yhat']]

# %%
df.head()
# Out:
#    waiting  eruptions      yhat
# 1       79      3.600  4.100592
# 2       54      1.800  2.209893
# 3       74      3.333  3.722452
# 4       62      2.283  2.814917
# 5       85      4.533  4.554360

# %%
melt = df.melt(id_vars = ["waiting"])

# %%
melt
# Out:
#      waiting   variable     value
# 0         79  eruptions  3.600000
# 1         54  eruptions  1.800000
# 2         74  eruptions  3.333000
# 3         62  eruptions  2.283000
# 4         85  eruptions  4.533000
# 5         55  eruptions  2.883000
# 6         88  eruptions  4.700000
# 7         85  eruptions  3.600000
# 8         51  eruptions  1.950000
# 9         85  eruptions  4.350000
# 10        54  eruptions  1.833000
# 11        84  eruptions  3.917000
# 12        78  eruptions  4.200000
# 13        47  eruptions  1.750000
# 14        83  eruptions  4.700000
# 15        52  eruptions  2.167000
# 16        62  eruptions  1.750000
# 17        84  eruptions  4.800000
# 18        52  eruptions  1.600000
# 19        79  eruptions  4.250000
# 20        51  eruptions  1.800000
# 21        47  eruptions  1.750000
# 22        78  eruptions  3.450000
# 23        69  eruptions  3.067000
# 24        74  eruptions  4.533000
# 25        83  eruptions  3.600000
# ...

# %%
sns.relplot(data = melt, x = 'waiting', y = 'value', hue = 'variable', alpha = .6)
