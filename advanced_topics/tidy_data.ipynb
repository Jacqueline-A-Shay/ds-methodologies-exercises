# %% [markdown]
# # Tidy Data
#
# - tabular data
# - one value per cell
# - 1 var / column
# - 1 obs / row

# %%
import pandas as pd

# %% [markdown]
# ## One Variable in Multiple Columns
#
# - `melt`

# %%
df = pd.read_csv('./untidy_data/treatments.csv')
df
# Out:
#                  treatmenta  treatmentb  treatmentc
# 0    John Smith         NaN           2           0
# 1      Jane Doe        16.0          11           3
# 2  Mary Johnson         3.0           1           4

# %%
df.columns = ["subject_name", "treatment_a", "treatment_b", "treatment_c"]
df
# Out:
#    subject_name  treatment_a  treatment_b  treatment_c
# 0    John Smith          NaN            2            0
# 1      Jane Doe         16.0           11            3
# 2  Mary Johnson          3.0            1            4

# %%
df.melt()
# Out:
#         variable         value
# 0   subject_name    John Smith
# 1   subject_name      Jane Doe
# 2   subject_name  Mary Johnson
# 3    treatment_a           NaN
# 4    treatment_a            16
# 5    treatment_a             3
# 6    treatment_b             2
# 7    treatment_b            11
# 8    treatment_b             1
# 9    treatment_c             0
# 10   treatment_c             3
# 11   treatment_c             4

# %%
df.melt(id_vars = "subject_name", var_name = "treatment", value_name = "treatment_result")
# id_vars > specify which col to be indentifier
# value_var > columns to unpivot, if not specified, will be all remaining col (other than id_vars)
# var_name, name the col
# Out:
#    subject_name    treatment  treatment_result
# 0    John Smith  treatment_a               NaN
# 1      Jane Doe  treatment_a              16.0
# 2  Mary Johnson  treatment_a               3.0
# 3    John Smith  treatment_b               2.0
# 4      Jane Doe  treatment_b              11.0
# 5  Mary Johnson  treatment_b               1.0
# 6    John Smith  treatment_c               0.0
# 7      Jane Doe  treatment_c               3.0
# 8  Mary Johnson  treatment_c               4.0

# %%
df = df.melt(id_vars = "subject_name", var_name = "treatment", value_name = "treatment_result")

# %%
df.treatment = df.treatment.str.replace('treatment_', '')

# %%
df
# Out:
#    subject_name treatment  treatment_result
# 0    John Smith         a               NaN
# 1      Jane Doe         a              16.0
# 2  Mary Johnson         a               3.0
# 3    John Smith         b               2.0
# 4      Jane Doe         b              11.0
# 5  Mary Johnson         b               1.0
# 6    John Smith         c               0.0
# 7      Jane Doe         c               3.0
# 8  Mary Johnson         c               4.0

# %% [markdown]
# ## One Column With Multiple Variables
#
# - `set_index` + `unstack`
# - `pivot_table`

# %%
df = pd.read_csv('./untidy_data/students.csv')
df.head()
# Out:
#          date                 var          val
# 0  2019-02-04   n_late_from_break     4.028120
# 1  2019-02-04  coffee_consumption  5255.409740
# 2  2019-02-04      classroom_temp    67.000000
# 3  2019-02-05   n_late_from_break     2.101998
# 4  2019-02-05  coffee_consumption  8603.704719

# %%
# (value, row, column)
df.pivot_table('val','date','var')
# Out:
# var         classroom_temp  coffee_consumption  n_late_from_break
# date
# 2019-02-04            67.0         5255.409740           4.028120
# 2019-02-05            73.0         8603.704719           2.101998
# 2019-02-06            81.0         1801.498050           4.941244
# 2019-02-07            62.0         9282.959741           1.419342
# 2019-02-08            72.0         7558.270659           1.808919
# 2019-02-11            60.0         5731.008713           4.831584
# 2019-02-12            52.0         9547.673484           3.550830
# 2019-02-13            56.0         7114.931847           2.550362
# 2019-02-14            72.0         1977.295513           3.507548
# 2019-02-15            75.0         2254.674679           2.114379
# 2019-02-18            55.0         4819.981878           2.249609
# 2019-02-19            82.0         8628.442171           4.646607
# 2019-02-20            58.0         6905.019187           1.309552
# 2019-02-21            79.0         1414.705565           2.132542
# 2019-02-22            68.0         8894.846285           1.745758
# 2019-02-25            84.0         5982.280540           2.344274
# 2019-02-26            54.0         9121.391375           4.620919
# 2019-02-27            88.0         4412.125903           1.860681
# 2019-02-28            81.0         1693.233409           1.342123

# %% [markdown]
# ## More complex example

# %%
df = pd.read_csv('./untidy_data/sales.csv')
df
# Out:
#   Product  2016 Sales  2016 PPU  2017 Sales  2017 PPU  2018 Sales  2018 PPU
# 0       A         673         5         231         7         173         9
# 1       B         259         3         748         5         186         8
# 2       C         644         3         863         5         632         5
# 3       D         508         9         356        11         347        14

# %%
df = df.melt(id_vars = 'Product')

# %%
df['year'] = df.variable.str.extract(r'^(\d+)')

# %%
df.head()
# Out:
#   Product    variable  value  year
# 0       A  2016 Sales    673  2016
# 1       B  2016 Sales    259  2016
# 2       C  2016 Sales    644  2016
# 3       D  2016 Sales    508  2016
# 4       A    2016 PPU      5  2016

# %%
df['var_name'] = df.variable.str.extract(r'^\d+\s?(.*)$')

# %%
df.drop(columns = ['variable'], inplace = True)

# %%
df.head()
# Out:
#   Product  value  year  sales
# 0       A    673  2016  Sales
# 1       B    259  2016  Sales
# 2       C    644  2016  Sales
# 3       D    508  2016  Sales
# 4       A      5  2016    PPU

# %%
df.pivot_table('value', ['Product', 'year'])
# Out:
#               value
# Product year
# A       2016  339.0
#         2017  119.0
#         2018   91.0
# B       2016  131.0
#         2017  376.5
#         2018   97.0
# C       2016  323.5
#         2017  434.0
#         2018  318.5
# D       2016  258.5
#         2017  183.5
#         2018  180.5

# %%
df.pivot_table('value', ['Product', 'year'], 'var_name')
# Out:
# var_name      PPU  Sales
# Product year
# A       2016    5    673
#         2017    7    231
#         2018    9    173
# B       2016    3    259
#         2017    5    748
#         2018    8    186
# C       2016    3    644
#         2017    5    863
#         2018    5    632
# D       2016    9    508
#         2017   11    356
#         2018   14    347

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Attendance data

# %% [markdown]
# Load the attendance.csv file and calculate an attendnace percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.
#
# You should end up with this:
#
#
# | student | score  |
# | ------- | -----  |
# | Billy   | 0.2250 |
# | Jane    | 0.1875 |
# | John    | 0.7125 |
# | Sally   | 0.3625 |

# %%
df = pd.read_csv("./untidy_data/attendance.csv")

# %%
df.head()
# Out:
#   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P

# %%
df.rename(columns = {'Unnamed: 0': 'name'}, inplace = True)

# %%
df = df.melt(id_vars = "name", var_name = "date", value_name = "attendance")

# %%
df.head()
# Out:
#     name        date attendance
# 0  Sally  2018-01-01          P
# 1   Jane  2018-01-01          A
# 2  Billy  2018-01-01          A
# 3   John  2018-01-01          P
# 4  Sally  2018-01-02          T

# %%
df.attendance.value_counts()
# Out:
# T    14
# P     9
# A     6
# H     3
# Name: attendance, dtype: int64

# %%
x = df.attendance
condlist = ([
    x.str.contains('A'),
    x.str.contains('H'),
    x.str.contains('T'),
    x.str.contains('P')])
# when meeting the quiteria, do these math
choicelist = (-1,
              0.5,
              -0.1, 
              1)
# store info back into df after conversion
df['attendance'] = np.select(condlist, choicelist)

# %%
df.head()
# Out:
#     name        date  attendance
# 0  Sally  2018-01-01         1.0
# 1   Jane  2018-01-01        -1.0
# 2  Billy  2018-01-01        -1.0
# 3   John  2018-01-01         1.0
# 4  Sally  2018-01-02        -0.1

# %%
df.pivot_table('attendance', ['name'], aggfunc=np.mean)
# Out:
#        attendance
# name
# Billy     -0.2250
# Jane      -0.1875
# John       0.6625
# Sally      0.1375

# %% [markdown]
# Coffee Levels
#
# - Read the coffee_levels.csv file.
# - Transform the data so that each carafe is in it's own column.
# - Is this the best shape for the data?

# %%
df = pd.read_csv("./untidy_data/coffee_levels.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# hour             30 non-null int64
# coffee_carafe    30 non-null object
# coffee_amount    30 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 848.0+ bytes

# %%
df.hour.value_counts()
# Out:
# 17    3
# 16    3
# 15    3
# 14    3
# 13    3
# 12    3
# 11    3
# 10    3
# 9     3
# 8     3
# Name: hour, dtype: int64

# %%
df.coffee_carafe.value_counts()
# Out:
# z    10
# y    10
# x    10
# Name: coffee_carafe, dtype: int64

# %%
df.coffee_amount.value_counts()
# Out:
# 0.843279    1
# 0.183891    1
# 0.144644    1
# 0.898291    1
# 0.391560    1
# 0.058361    1
# 0.864464    1
# 0.915990    1
# 0.771947    1
# 0.280621    1
# 0.544676    1
# 0.451018    1
# 0.521502    1
# 0.023163    1
# 0.436677    1
# 0.398520    1
# 0.335533    1
# 0.436364    1
# 0.235529    1
# 0.311495    1
# 0.215043    1
# 0.997464    1
# 0.017009    1
# 0.999264    1
# 0.310711    1
# 0.507288    1
# 0.594126    1
# 0.144928    1
# 0.816164    1
# 0.189297    1
# Name: coffee_amount, dtype: int64

# %%
df.head()
# Out:
#    hour coffee_carafe  coffee_amount
# 0     8             x       0.816164
# 1     9             x       0.451018
# 2    10             x       0.843279
# 3    11             x       0.335533
# 4    12             x       0.898291

# %%
df.pivot_table('coffee_carafe', ['hour','coffee_amount'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-144-754c4b176c1e> in <module>
# ----> 1 df.pivot_table('coffee_carafe', ['hour','coffee_amount'])
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6087             dropna=dropna,
#    6088             margins_name=margins_name,
# -> 6089             observed=observed,
#    6090         )
#    6091
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     303         if f is not None:
#     304             if callable(f):
# --> 305                 return f(*args, **kwargs)
#     306
#     307             # people may try to aggregate on a non-callable attribute
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %% [markdown]
# Cake Recipes
#
# Read the cake_recipes.csv data. This data set contains cake tastiness scores for combinations of different recipes, oven rack positions, and oven temperatures.
# Tidy the data as necessary.
# Which recipe, on average, is the best? recipe b
# Which oven temperature, on average, produces the best results? 275
# Which combination of recipe, rack position, and temperature gives the best result? recipe b, bottom rack, 300 degrees
